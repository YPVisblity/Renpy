# %%
import pybryt

# %%
from collections import deque
graph = {
    "A": ["B", "C"],
    "B": ["A", "D"],
    "C": ["A", "D"],
    "D": ["B", "C", "E"],
    "E": ["D"],
}

# 範例：DFS（遞迴實作，已完成，供參考）
def dfs(graph, start, visited=None, result=None):
    if visited is None:
        visited = set()
        result = []
    visited.add(start)
    result.append(start)
    for neighbor in graph[start]:
        if neighbor not in visited:
            dfs(graph, neighbor, visited, result)
    return result

print(dfs(graph, "A"))   # 可能輸出：['A', 'B', 'D', 'C', 'E']（依鄰接順序而定）
# Out:
# ['A', 'B', 'D', 'C', 'E']

# %%
def shortest_path(graph, start, end):
    """利用 BFS 找出 start 到 end 的最短路徑，回傳節點 list；不連通則回傳 None"""
    if start == end:
        return [start]

    visited = {start}
    queue = deque([start])
    predecessor = {start: None}

    while queue:
        node = queue.popleft()
        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                predecessor[neighbor] = node
                if neighbor == end:
                    # 找到終點，開始回推路徑
                    path = []
                    step = end
                    while step is not None:
                        path.append(step)
                        step = predecessor[step]
                    path.reverse()
                    return path
                queue.append(neighbor)

    return None  # 走完整個佇列都沒找到 end，代表不連通


# ===== 自我檢查 =====
path = shortest_path(graph, "A", "E")
assert path in (["A", "B", "D", "E"], ["A", "C", "D", "E"])
assert shortest_path(graph, "A", "A") == ["A"]

print("恭喜完成所有關卡！你已經取得「迷宮之城探險家」徽章，正式畢業成為資料結構大師！")
# Out:
# 恭喜完成所有關卡！你已經取得「迷宮之城探險家」徽章，正式畢業成為資料結構大師！

# %%
path_result = shortest_path(graph, "A", "E")
path_is_valid = path_result in (["A", "B", "D", "E"], ["A", "C", "D", "E"])

same_node_result = shortest_path(graph, "A", "A")
same_node_is_valid = (same_node_result == ["A"])

pybryt.Value(True, name="shortest_path_valid",
    success_message="找到一條合法的最短路徑",
    failure_message="shortest_path(graph,'A','E') 回傳的路徑不是合法最短路徑")

pybryt.Value(True, name="shortest_path_same_node",
    success_message="起點等於終點時正確回傳",
    failure_message="shortest_path(graph,'A','A') 應回傳['A']")
# Out:
# pybryt.Value
