# %%
# 認識變數
# 蘋果的價格為26元，請問小明購買6個蘋果需要多少錢?	請用value(x,y)計算蘋果總價為何?

# 在這裡寫程式
def value(x,y):
    total=x*y
    if x == 0 or y == 0:
        return "EOFError"
    else:
        return total

# %%
value(26,6)
