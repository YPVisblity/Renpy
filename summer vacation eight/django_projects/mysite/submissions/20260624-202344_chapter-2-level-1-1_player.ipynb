# %%
# 等差數列
# 請建立一個sequence串列後使用公式term = a + i * d計算等差數列。

def generate_arithmetic_sequence(a, d, n):

    result = []

    for i in range(n):
        result.append(a + i * d)

    return result

# %%
val = generate_arithmetic_sequence(2,3,5)
val
