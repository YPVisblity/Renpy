# %%
# 模擬學生寫的程式碼內容
student_code_content = """
def student_binary_search(arr, l, r, x):
    while (l <= r):
        m = (l + r) // 2
        if (arr[m] == x):
            return m
        if (arr[m] < x):
            l = m + 1
        else:
            r = m - 1
    return -1
"""
# 把這段內容存成實體檔案 subm.py
with open("subm.ipynb", "w", encoding="utf-8") as f:
    f.write(student_code_content)

print("✅ 學生作業 subm.py 已存檔成功！")
# Out:
# ✅ 學生作業 subm.py 已存檔成功！
