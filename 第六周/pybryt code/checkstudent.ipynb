# %%
# import asyncio
# asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
import pybryt
ref1 = pybryt.ReferenceImplementation.load('binarysearch_algo.pkl')
student = pybryt.StudentImplementation("student_.ipynb", timeout=60)
result = student.check(ref1)
print(result)
# Out:
# ReferenceResult([
#   AnnotationResult(satisfied=False, annotation=pybryt.Value),
#   AnnotationResult(satisfied=True, annotation=pybryt.Value),
#   AnnotationResult(satisfied=True, annotation=pybryt.Value)
# ])

# %%
import asyncio
asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

import pybryt
ref1 = pybryt.ReferenceImplementation.load('binarysearch_algo.pkl')
student = pybryt.StudentImplementation("student_.ipynb")
result = student.check(ref1)
print(result)
# Out:
# ReferenceResult([
#   AnnotationResult(satisfied=False, annotation=pybryt.Value),
#   AnnotationResult(satisfied=True, annotation=pybryt.Value),
#   AnnotationResult(satisfied=True, annotation=pybryt.Value)
# ])

# %%
import pybryt.execution
import inspect
print(inspect.getsource(pybryt.execution.execute_notebook))

# %%
from tempfile import mkstemp
_, fp = mkstemp()
print(fp)  # 看看路徑長什麼樣子

# %%
import os
print(os.path.exists("student_.ipynb"))
